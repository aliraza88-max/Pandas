# %%
import pandas as pd

# %%
df=pd.DataFrame({"Category":["region",'  date','Month-year']})

# %%
print(df)
# Out:
#      Category
# 0      region
# 1        date
# 2  Month-year

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# strip spaces and convert to lower case

df["Category_clean"]=df["Category"].str.strip().str.lower()
df
# Out:
#      Category Category_clean
# 0      region         region
# 1        date           date
# 2  Month-year     month-year

# %%
# Replace hyphens with space

df["Category_clean"]=df["Category_clean"].str

# %% [markdown]
# ### **Pandas Fundamentals**

# %%
! pip install pandas

# %%
import pandas as pd

# %%
set_01=pd.Series([10,10,20,30,40,50,60,60,70,70],index=["a","b","c","d","e","f","g","h","i","j"])
set_01
# Out:
# a    10
# b    10
# c    20
# d    30
# e    40
# f    50
# g    60
# h    60
# i    70
# j    70
# dtype: int64

# %%
set_01.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
set_01.values
# Out:
# array([10, 10, 20, 30, 40, 50, 60, 60, 70, 70])

# %%
set_01.dtype
# Out:
# dtype('int64')

# %%
set_01.head
# Out:
# <bound method NDFrame.head of a    10
# b    10
# c    20
# d    30
# e    40
# f    50
# g    60
# h    60
# i    70
# j    70
# dtype: int64>

# %%
set_01.tail
# Out:
# <bound method NDFrame.tail of a    10
# b    10
# c    20
# d    30
# e    40
# f    50
# g    60
# h    60
# i    70
# j    70
# dtype: int64>

# %%
set_01.value_counts()
# Out:
# <bound method IndexOpsMixin.value_counts of a    10
# b    10
# c    20
# d    30
# e    40
# f    50
# g    60
# h    60
# i    70
# j    70
# dtype: int64>
